# %%
# Save your credentials for the IBM Quantum Platform locally with this code:
# get token (API key and CRN) from https://quantum.cloud.ibm.com:
# 1. create an Open Plan instance, and copy the CRN from the dashboard 
# 2. create an API key


instance="<CRN>", 
token="<your-api-key>", # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard


from qiskit_ibm_runtime import QiskitRuntimeService
QiskitRuntimeService.save_account(
    token=token, 
    instance=instance,
    overwrite=True,
    channel="ibm_cloud" # `channel` distinguishes between different account types
)
